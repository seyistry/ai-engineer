# %% [markdown]
# # White wine

# %%
# importing neccessary libraries for ML model and parameter tuning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from zipfile import ZipFile
import joblib

# %% [markdown]
# ## Load data

# %%
# file path
path=r"C:\Users\OLASQUARE\Downloads\wine+quality.zip"

# Extract and checking the zip file for file names
with ZipFile(path, 'r') as zip_ref:
    zip_ref.printdir()
data= pd
# Out:
# File Name                                             Modified             Size
# winequality-red.csv                            2023-05-22 22:24:00        84199
# winequality-white.csv                          2023-05-22 22:24:00       264426
# winequality.names                              2023-05-22 22:24:00         3305

# %%
# accessing the particular dataset need
with ZipFile(path) as zip_ref:
    with zip_ref.open("winequality-white.csv") as f:
        white_wine= pd.read_csv(f, sep=";")

# %%
# copy data for safety
df=white_wine.copy()
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# checking the data distribution (inspect)
df.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_7bf7e_row0_col0, #T_7bf7e_row1_col0, #T_7bf7e_row1_col1, #T_7bf7e_row1_col2, #T_7bf7e_row1_col4, #T_7bf7e_row1_col5, #T_7bf7e_row1_col6, #T_7bf7e_row1_col7, #T_7bf7e_row2_col0, #T_7bf7e_row2_col1, #T_7bf7e_row2_col2, #T_7bf7e_row2_col3, #T_7bf7e_row2_col4, #T_7bf7e_row2_col5, #T_7bf7e_row2_col6, #T_7bf7e_row2_col7, #T_7bf7e_row3_col0, #T_7bf7e_row4_col0, #T_7bf7e_row4_col1, #T_7bf7e_row4_col2, #T_7bf7e_row4_col3, #T_7bf7e_row4_col4, #T_7bf7e_row4_col5, #T_7bf7e_row4_col6, #T_7bf7e_row4_col7, #T_7bf7e_row5_col0, #T_7bf7e_row6_col0, #T_7bf7e_row7_col0, #T_7bf7e_row7_col2, #T_7bf7e_row7_col7, #T_7bf7e_row8_col0, #T_7bf7e_row8_col2, #T_7bf7e_row9_col0, #T_7bf7e_row9_col1, #T_7bf7e_row9_col2, #T_7bf7e_row9_col4, #T_7bf7e_row9_col5, #T_7bf7e_row9_col6, #T_7bf7e_row9_col7, #T_7bf7e_row10_col0, #T_7bf7e_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7bf7e_row0_col1, #T_7bf7e_row0_col5, #T_7bf7e_row0_col6, #T_7bf7e_row3_col1, #T_7bf7e_row11_col4, #T_7bf7e_row11_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_7bf7e_row0_col2, #T_7bf7e_row8_col1, #T_7bf7e_row8_col5, #T_7bf7e_row11_col2, #T_7bf7e_row11_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_7bf7e_row0_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_7bf7e_row0_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_7bf7e_row0_col7, #T_7bf7e_row10_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_7bf7e_row1_col3, #T_7bf7e_row7_col4, #T_7bf7e_row8_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_7bf7e_row3_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_7bf7e_row3_col3, #T_7bf7e_row10_col6 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_7bf7e_row3_col4, #T_7bf7e_row8_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7bf7e_row3_col5, #T_7bf7e_row11_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_7bf7e_row3_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_7bf7e_row3_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_7bf7e_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_7bf7e_row5_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_7bf7e_row5_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_7bf7e_row5_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_7bf7e_row5_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_7bf7e_row5_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_7bf7e_row5_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_7bf7e_row6_col1, #T_7bf7e_row6_col2, #T_7bf7e_row6_col3, #T_7bf7e_row6_col4, #T_7bf7e_row6_col5, #T_7bf7e_row6_col6, #T_7bf7e_row6_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7bf7e_row7_col1, #T_7bf7e_row7_col5, #T_7bf7e_row7_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_7bf7e_row7_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_7bf7e_row8_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_7bf7e_row8_col4, #T_7bf7e_row10_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_7bf7e_row9_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_7bf7e_row10_col1, #T_7bf7e_row10_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_7bf7e_row10_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_7bf7e_row10_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7bf7e_row11_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_7bf7e_row11_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# </style>
# <table id="T_7bf7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bf7e_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_7bf7e_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_7bf7e_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_7bf7e_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_7bf7e_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_7bf7e_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_7bf7e_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_7bf7e_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bf7e_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_7bf7e_row0_col0" class="data row0 col0" >4898.000000</td>
#       <td id="T_7bf7e_row0_col1" class="data row0 col1" >6.854788</td>
#       <td id="T_7bf7e_row0_col2" class="data row0 col2" >0.843868</td>
#       <td id="T_7bf7e_row0_col3" class="data row0 col3" >3.800000</td>
#       <td id="T_7bf7e_row0_col4" class="data row0 col4" >6.300000</td>
#       <td id="T_7bf7e_row0_col5" class="data row0 col5" >6.800000</td>
#       <td id="T_7bf7e_row0_col6" class="data row0 col6" >7.300000</td>
#       <td id="T_7bf7e_row0_col7" class="data row0 col7" >14.200000</td>
#     </tr>
#     <tr>
#       <th id="T_7bf7e_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_7bf7e_row1_col0" class="data row1 col0" >4898.000000</td>
#       <td id="T_7bf7e_row1_col1" class="data row1 col1" >0.278241</td>
#       <td id="T_7bf7e_row1_col2" class="data row1 col2" >0.100795</td>
#       <td id="T_7bf7e_row1_col3" class="data row1 col3" >0.080000</td>
#       <td id="T_7bf7e_row1_col4" class="data row1 col4" >0.210000</td>
#       <td id="T_7bf7e_row1_col5" class="data row1 col5" >0.260000</td>
#       <td id="T_7bf7e_row1_col6" class="data row1 col6" >0.320000</td>
#       <td id="T_7bf7e_row1_col7" class="data row1 col7" >1.100000</td>
#     </tr>
#     <tr>
#       <th id="T_7bf7e_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_7bf7e_row2_col0" class="data row2 col0" >4898.000000</td>
#       <td id="T_7bf7e_row2_col1" class="data row2 col1" >0.334192</td>
#       <td id="T_7bf7e_row2_col2" class="data row2 col2" >0.121020</td>
#       <td id="T_7bf7e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_7bf7e_row2_col4" class="data row2 col4" >0.270000</td>
#       <td id="T_7bf7e_row2_col5" class="data row2 col5" >0.320000</td>
#       <td id="T_7bf7e_row2_col6" class="data row2 col6" >0.390000</td>
#       <td id="T_7bf7e_row2_col7" class="data row2 col7" >1.660000</td>
#     </tr>
#     <tr>
#       <th id="T_7bf7e_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_7bf7e_row3_col0" class="data row3 col0" >4898.000000</td>
#       <td id="T_7bf7e_row3_col1" class="data row3 col1" >6.391415</td>
#       <td id="T_7bf7e_row3_col2" class="data row3 col2" >5.072058</td>
#       <td id="T_7bf7e_row3_col3" class="data row3 col3" >0.600000</td>
#       <td id="T_7bf7e_row3_col4" class="data row3 col4" >1.700000</td>
#       <td id="T_7bf7e_row3_col5" class="data row3 col5" >5.200000</td>
#       <td id="T_7bf7e_row3_col6" class="data row3 col6" >9.900000</td>
#       <td id="T_7bf7e_row3_col7" class="data row3 col7" >65.800000</td>
#     </tr>
#     <tr>
#       <th id="T_7bf7e_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_7bf7e_row4_col0" class="data row4 col0" >4898.000000</td>
#       <td id="T_7bf7e_row4_col1" class="data row4 col1" >0.045772</td>
#       <td id="T_7bf7e_row4_col2" class="data row4 col2" >0.021848</td>
#       <td id="T_7bf7e_row4_col3" class="data row4 col3" >0.009000</td>
#       <td id="T_7bf7e_row4_col4" class="data row4 col4" >0.036000</td>
#       <td id="T_7bf7e_row4_col5" class="data row4 col5" >0.043000</td>
#       <td id="T_7bf7e_row4_col6" class="data row4 col6" >0.050000</td>
#       <td id="T_7bf7e_row4_col7" class="data row4 col7" >0.346000</td>
#     </tr>
#     <tr>
#       <th id="T_7bf7e_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_7bf7e_row5_col0" class="data row5 col0" >4898.000000</td>
#       <td id="T_7bf7e_row5_col1" class="data row5 col1" >35.308085</td>
#       <td id="T_7bf7e_row5_col2" class="data row5 col2" >17.007137</td>
#       <td id="T_7bf7e_row5_col3" class="da

# %% [markdown]
# ## Check missing value

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %% [markdown]
# ## Reclassify

# %%
# classifying the wine quality from Best to Bad in range ([6, 5, 7, 8, 4, 3, 9])
df.replace({'quality':{9:"Best",8:"Best", 7:"Good",6:"Good",5:"Average",4:"Bad",3:"Bad"}}, inplace=True)

# %% [markdown]
# ## Split (feataures and target)

# %%
X= df.drop(columns="quality") #features
y=df["quality"] #target

# %% [markdown]
# ## Scalling

# %%
scale= MinMaxScaler(feature_range=(0,1))
X_scaled=scale.fit_transform(X)

# %% [markdown]
# ## Splitting dataset

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,random_state=234,stratify=y,test_size=0.2)

# %% [markdown]
# ## Modelling

# %%
# let put all our model together for easy looping
models={
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Decision Tree':DecisionTreeClassifier(),
    'K nearest Neighbors': KNeighborsClassifier(),
    'SVM': SVC(),
    'Naive Bayes': GaussianNB()
}

# %%
# initialize a dictionary to store the models results
results={}
for model_name, model in models.items():
    print(f"{model_name} is in training section...")
    model.fit(X_train,y_train)
    y_pred= model.predict(X_test)
    accuracy= accuracy_score(y_test,y_pred)
    results[model_name]=accuracy
    print(f'{model_name} Accuracy:{accuracy:.2f}')

    # let add confusion matrix
    cm= confusion_matrix(y_test,y_pred)
    display= ConfusionMatrixDisplay(cm)

    # plot for visual and make the model name title
    display.plot(cmap="Blues")
    plt.title(f'Confusion Matrix: {model_name}')
    plt.show()

# Let print the results in a dataframe for better visualization
results_df= pd.DataFrame(results.items(), columns=['Model', 'Accuracy'])
results_df= results_df.sort_values(by='Accuracy', ascending=False)
results_df.reset_index(drop=True, inplace=True)
results_df
# Out:
# Logistic Regression is in training section...
# Logistic Regression Accuracy:0.71
# Random Forest is in training section...
# Random Forest Accuracy:0.80
# Decision Tree is in training section...
# Decision Tree Accuracy:0.73
# K nearest Neighbors is in training section...
# K nearest Neighbors Accuracy:0.71
# SVM is in training section...
# SVM Accuracy:0.72
# Naive Bayes is in training section...
# Naive Bayes Accuracy:0.63
#                  Model  Accuracy
# 0        Random Forest  0.802041
# 1        Decision Tree  0.725510
# 2                  SVM  0.717347
# 3  K nearest Neighbors  0.710204
# 4  Logistic Regression  0.705102
# 5          Naive Bayes  0.628571

# %% [markdown]
# ## Hyper Parameter Tunning: Best model selection for Tunning

# %% [markdown]
# **Based on the accuracy score from Random Forest (Accuracy: 80%).**
# **I will work on turning the Random Forest**

# %%
# let turn Random Forest
rf= RandomForestClassifier()
# display default parameters
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# let's create a parameter grid for RandomizedSearchCV
param_grid={
    'n_estimators':[50,100,200],
    'max_depth':[10,20,30],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
}

# let define RandomsearchCV (we use randomsearch to reduce computational cost)
rf_random= RandomizedSearchCV(estimator=rf, param_distributions=param_grid, n_iter=10, cv=5, verbose=2, random_state=234, n_jobs=-1)
rf_random.fit(X_train,y_train)
# Print best parameters from random search
print(f"Best Parameters from Randomized Search: {rf_random.best_params_}")

# let do cross validation for the best estimator
best_rf= rf_random.best_estimator_
cv_scores= cross_val_score(best_rf,X_train,y_train, cv=5)
print(f"Cross-validation scores for Random Forest: {cv_scores}")
print(f"Mean Cross-validation score: {np.mean(cv_scores):.2f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Parameters from Randomized Search: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 20}
# Cross-validation scores for Random Forest: [0.78188776 0.74872449 0.76403061 0.79054917 0.75734355]
# Mean Cross-validation score: 0.77

# %% [markdown]
# ## Predict with Best tuned model

# %%
# let use the best model to predict on test set
y_pred_best= best_rf.predict(X_test)
# Display classification report
print("Classification Report for Best Random Forest Model:")
print(classification_report(y_test,y_pred_best))
# Out:
# Classification Report for Best Random Forest Model:
#               precision    recall  f1-score   support
#
#      Average       0.75      0.71      0.73       291
#          Bad       0.67      0.16      0.26        37
#         Best       0.94      0.42      0.58        36
#         Good       0.83      0.91      0.87       616
#
#     accuracy                           0.80       980
#    macro avg       0.79      0.55      0.61       980
# weighted avg       0.80      0.80      0.79       980

# %% [markdown]
# ## Saving the data

# %%
## Saving the data
joblib.dump(best_rf, 'best_model.pkl')

# let save the scaler too
joblib.dump(scale, 'scaler.pkl')
print("=="*30)
print("Best Random Forest model and scaler have been saved successfully.")
print("=="*30)
# Out:
# ============================================================
# Best Random Forest model and scaler have been saved successfully.
# ============================================================
