# %%
# pip install together

# %%
from together import Together

# %%
api_key = "c9f22dbdf4cb34d69c9c400dd575a0152c736eeb09c1758bd9816"

# %%
# initialize client
client = Together(api_key=api_key) # auth defaults to os.environ.get("TOGETHER_API_KEY")

# %% [markdown]
# | Parameter            | Purpose                     |
# | -------------------- | --------------------------- |
# | `messages`           | Conversation input          |
# | `model`              | Which AI engine             |
# | `max_tokens`         | Limit output length         |
# | `stop`               | Force stopping              |
# | `temperature`        | Creativity                  |
# | `top_p`              | Nucleus sampling            |
# | `top_k`              | Token filtering             |
# | `min_p`              | Token probability threshold |
# | `presence_penalty`   | New topic encouragement     |
# | `frequency_penalty`  | Reduce repeated words       |
# | `repetition_penalty` | Reduce token loops          |
# | `logit_bias`         | Force/ban tokens            |
# | `seed`               | Deterministic output        |
# | `stream`             | Real-time output            |
# | `logprobs`           | Return token probabilities  |
# | `echo`               | Echo prompt                 |
# | `n`                  | Number of completions       |
# | `response_format`    | Force JSON or schema        |
# | `tools`              | Enable tool calling         |
# | `tool_choice`        | Control tool behavior       |
# | `safety_model`       | Override safety settings    |

# %% [markdown]
# | Role          | Purpose                                       | Typical Usage                     |
# | ------------- | --------------------------------------------- | --------------------------------- |
# | **system**    | High-level instructions guiding the assistant | Set rules, tone, or persona       |
# | **user**      | Message from the human                        | Questions, commands, conversation |
# | **assistant** | Message from the AI                           | AI responses and reasoning        |
# | **tool**      | Output returned by a called tool              | After tool execution              |
# | **developer** | Developer instructions (optional mode)        | Structured or restricted tasks    |

# %%
response = client.chat.completions.create(
    model="moonshotai/Kimi-K2-Thinking",
    messages=[
      {
        "role": "user",
        "content": "What are some fun things to do in New York?"
      }
    ]
)
print(response.choices[0].message.content)
# Out:
# New York City offers endless fun—here are some top picks by category:
#
# ### **Iconic Classics (Done Right)**
# - **Walk the Brooklyn Bridge** at sunrise (Brooklyn→Manhattan for the best skyline views)
# - **Statue of Liberty**: Take the (free) Staten Island Ferry for skyline views, or book ahead for pedestal/crown access
# - **Times Square**: Go once at night for the lights, then escape to nearby Hell's Kitchen for better food
# - **Grand Central Terminal**: See the "whispering gallery" by the Oyster Bar and grab a cocktail at the Campbell
#
# ### **Parks & Outdoor Vibes**
# - **Central Park**: Rent a rowboat at the Loeb Boathouse, visit Bethesda Fountain, or join a free summer concert
# - **The High Line**: Walk this elevated park from Hudson Yards to Chelsea Market (great for people-watching)
# - **Governors Island**: Rent a free bike, explore the hammock grove, and enjoy car-free streets (weekends, May-Oct)
# ...
